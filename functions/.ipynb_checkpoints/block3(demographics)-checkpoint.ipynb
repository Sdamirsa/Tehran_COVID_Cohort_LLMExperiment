# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("ClincolabratoryAll_Labeled_Cleaned_Anonynimized.xlsx")
block3 = df.loc[: , 'Demographic_Age':'Demographic_Weight']

# %%
def fun3(info):

    if info[0]=="Null" or info[0]=='0':
        a ="age is unavailable. "
    else:
        a ="patient age is "+info[0]+". "
        
    if info[1]=="Male" or info[1]=="1":
        b= "gender is Male. "
    elif info[1]=="Female" or "2":
        b = "gender is Female. "
    else:
        b= "gender is not clear. "

    if info[2]=='NAN':
        c = " height is unavailable. "
    else:
        c=" height is "+str(info[2])+". "
        
    if info[3]=='NAN':
        d= ' weight is unavailable. '
    else:
        d = "weight is "+str(info[3])+" Kilograms. "
    n=(a+b+c+d)
    return(n)


lis3=[]
for i in block3.index:
    if i!=0:
        lis = []
        for a in block3.loc[i , : ]:
            lis.append(str(a))
        v=fun3(lis)
        lis3.append(v)

print(lis3)
# Out:
# ['patient age is 33. gender is Male.  height is 174. weight is 120 Kilograms. ', 'patient age is 44. gender is Male.  height is 175. weight is 78 Kilograms. ', 'patient age is 50. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 71. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 71. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 72. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 69. gender is Female.  height is 165. weight is 80 Kilograms. ', 'patient age is 57. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 59. gender is Male.  height is 172. weight is 88 Kilograms. ', 'patient age is 60. gender is Male.  height is 175. weight is 95 Kilograms. ', 'patient age is 45. gender is Female.  height is 160. weight is 120 Kilograms. ', 'patient age is 71. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 54. gender is Male.  height is 178. weight is 95 Kilograms. ', 'patient age is 58. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 65. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 65. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 88. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 88. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 83. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 93. gender is Female.  height is 160. weight is 80 Kilograms. ', 'patient age is 74. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 48. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 75. gender is Female.  height is 169. weight is 125 Kilograms. ', 'patient age is 47. gender is Male.  height is 175. weight is 70 Kilograms. ', 'patient age is 62. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 69. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 85. gender is Female.  height is 165. weight is 80 Kilograms. ', 'patient age is 66. gender is Male.  height is 175. weight is 80 Kilograms. ', 'patient age is 60. gender is Female.  height is 156. weight is 59 Kilograms. ', 'patient age is 72. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 78. gender is Male.  height is 170. weight is 70 Kilograms. ', 'patient age is 89. gender is Female.  height is 160. weight is 50 Kilograms. ', 'patient age is 43. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 60. gender is Male.  height is unavailable.  weight is unavailable. ', 'patient age is 60. gender is Male.  height is 175. weight is 85 Kilograms. ', 'patient age is 71. gender is Male.  height is 162. weight is 80 Kilograms. ', 'patient age is 56. gender is Male.  height is 175. weight is 88 Kilograms. ', 'patient age is 46. gender is Female.  height is 154. weight is 64 Kilograms. ', 'patient age is 42. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 50. gender is Female.  height is 160. weight is 75 Kilograms. ', 'patient age is 56. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 69. gender is Female.  height is 154. weight is 68 Kilograms. ', 'patient age is 57. gender is Female.  height is 177. weight is 96 Kilograms. ', 'patient age is 82. gender is Female.  height is unavailable.  weight is unavailable. ', 'patient age is 57. gender is Male.  height is 180. weight is 85 Kilograms. ', 'patient age is 61. gender is Female.  height is 165. weight is 80 Kilograms. ', 'patient age is 56. gender is Male.  height is 176. weight is 110 Kilograms. ', 'patient age is 64. gender is Female.  height is unavailable.  wei ...

# %%
x= 0
for i in lis3:
    x=x+1
    print(x)
    print(i)
# Out:
# 1
# patient age is 33. gender is Male.  height is 174. weight is 120 Kilograms.
# 2
# patient age is 44. gender is Male.  height is 175. weight is 78 Kilograms.
# 3
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 4
# patient age is 71. gender is Male.  height is unavailable.  weight is unavailable.
# 5
# patient age is 71. gender is Male.  height is unavailable.  weight is unavailable.
# 6
# patient age is 72. gender is Female.  height is unavailable.  weight is unavailable.
# 7
# patient age is 69. gender is Female.  height is 165. weight is 80 Kilograms.
# 8
# patient age is 57. gender is Male.  height is unavailable.  weight is unavailable.
# 9
# patient age is 59. gender is Male.  height is 172. weight is 88 Kilograms.
# 10
# patient age is 60. gender is Male.  height is 175. weight is 95 Kilograms.
# 11
# patient age is 45. gender is Female.  height is 160. weight is 120 Kilograms.
# 12
# patient age is 71. gender is Female.  height is unavailable.  weight is unavailable.
# 13
# patient age is 54. gender is Male.  height is 178. weight is 95 Kilograms.
# 14
# patient age is 58. gender is Male.  height is unavailable.  weight is unavailable.
# 15
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 16
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 17
# patient age is 88. gender is Male.  height is unavailable.  weight is unavailable.
# 18
# patient age is 88. gender is Male.  height is unavailable.  weight is unavailable.
# 19
# patient age is 83. gender is Male.  height is unavailable.  weight is unavailable.
# 20
# patient age is 93. gender is Female.  height is 160. weight is 80 Kilograms.
# 21
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 22
# patient age is 48. gender is Female.  height is unavailable.  weight is unavailable.
# 23
# patient age is 75. gender is Female.  height is 169. weight is 125 Kilograms.
# 24
# patient age is 47. gender is Male.  height is 175. weight is 70 Kilograms.
# 25
# patient age is 62. gender is Male.  height is unavailable.  weight is unavailable.
# 26
# patient age is 69. gender is Female.  height is unavailable.  weight is unavailable.
# 27
# patient age is 85. gender is Female.  height is 165. weight is 80 Kilograms.
# 28
# patient age is 66. gender is Male.  height is 175. weight is 80 Kilograms.
# 29
# patient age is 60. gender is Female.  height is 156. weight is 59 Kilograms.
# 30
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 31
# patient age is 78. gender is Male.  height is 170. weight is 70 Kilograms.
# 32
# patient age is 89. gender is Female.  height is 160. weight is 50 Kilograms.
# 33
# patient age is 43. gender is Female.  height is unavailable.  weight is unavailable.
# 34
# patient age is 60. gender is Male.  height is unavailable.  weight is unavailable.
# 35
# patient age is 60. gender is Male.  height is 175. weight is 85 Kilograms.
# 36
# patient age is 71. gender is Male.  height is 162. weight is 80 Kilograms.
# 37
# patient age is 56. gender is Male.  height is 175. weight is 88 Kilograms.
# 38
# patient age is 46. gender is Female.  height is 154. weight is 64 Kilograms.
# 39
# patient age is 42. gender is Female.  height is unavailable.  weight is unavailable.
# 40
# patient age is 50. gender is Female.  height is 160. weight is 75 Kilograms.
# 41
# patient age is 56. gender is Female.  height is unavailable.  weight is unavailable.
# 42
# patient age is 69. gender is Female.  height is 154. weight is 68 Kilograms.
# 43
# patient age is 57. gender is Female.  height is 177. weight is 96 Kilograms.
# 44
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 45
# patient age is 57. gender is Male.  height is 180. weight is 85 Kilograms.
# 46
# patient age is 61. gender is Female.  height is 165. weight is 80 Kilograms.
# 47
# patient age is 56. gender is Male.  height is 176. weight is 110 Kilograms.
# 48
# patient age is 64. gender is Female.  height is unavailable.  weight is unavailable.
# 49
# patient age is 85. gender is Female.  height is unavailable. weight is 90 Kilograms.
# 50
# patient age is 78. gender is Female.  height is 162. weight is 88 Kilograms.
# 51
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 52
# patient age is 79. gender is Female.  height is unavailable.  weight is unavailable.
# 53
# patient age is 64. gender is Female.  height is 158. weight is 90 Kilograms.
# 54
# patient age is 81. gender is Male.  height is unavailable.  weight is unavailable.
# 55
# patient age is 67. gender is Male.  height is 169. weight is 78 Kilograms.
# 56
# patient age is 52. gender is Male.  height is 170. weight is 90 Kilograms.
# 57
# patient age is 76. gender is Female.  height is 153. weight is 65 Kilograms.
# 58
# patient age is 55. gender is Female.  height is 160.  weight is unavailable.
# 59
# patient age is 40. gender is Male.  height is unavailable.  weight is unavailable.
# 60
# patient age is 38. gender is Male.  height is unavailable.  weight is unavailable.
# 61
# patient age is 86. gender is Female.  height is unavailable.  weight is unavailable.
# 62
# patient age is 60. gender is Female.  height is 155. weight is 80 Kilograms.
# 63
# patient age is 64. gender is Male.  height is 175. weight is 74 Kilograms.
# 64
# patient age is 67. gender is Female.  height is unavailable.  weight is unavailable.
# 65
# patient age is 41. gender is Male.  height is unavailable.  weight is unavailable.
# 66
# patient age is 76. gender is Male.  height is unavailable.  weight is unavailable.
# 67
# patient age is 52. gender is Female.  height is unavailable.  weight is unavailable.
# 68
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 69
# patient age is 65. gender is Female.  height is unavailable.  weight is unavailable.
# 70
# patient age is 31. gender is Female.  height is 160. weight is 80 Kilograms.
# 71
# patient age is 64. gender is Male.  height is 170. weight is 90 Kilograms.
# 72
# patient age is 79. gender is Female.  height is 157. weight is 90 Kilograms.
# 73
# patient age is 63. gender is Female.  height is unavailable.  weight is unavailable.
# 74
# patient age is 92. gender is Male.  height is unavailable.  weight is unavailable.
# 75
# patient age is 81. gender is Female.  height is unavailable.  weight is unavailable.
# 76
# patient age is 77. gender is Female.  height is 160. weight is 65 Kilograms.
# 77
# patient age is 83. gender is Male.  height is 170. weight is 80 Kilograms.
# 78
# patient age is 48. gender is Female.  height is 158. weight is 93 Kilograms.
# 79
# patient age is 39. gender is Male.  height is 175. weight is 90 Kilograms.
# 80
# patient age is 82. gender is Male.  height is unavailable.  weight is unavailable.
# 81
# patient age is 82. gender is Male.  height is 165. weight is 55 Kilograms.
# 82
# patient age is 78. gender is Female.  height is unavailable.  weight is unavailable.
# 83
# patient age is 70. gender is Male.  height is 160. weight is 66 Kilograms.
# 84
# patient age is 45. gender is Female.  height is 156. weight is 85 Kilograms.
# 85
# patient age is 54. gender is Female.  height is 165. weight is 70 Kilograms.
# 86
# patient age is 48. gender is Male.  height is 181. weight is 85 Kilograms.
# 87
# patient age is 56. gender is Female.  height is unavailable.  weight is unavailable.
# 88
# patient age is 67. gender is Male.  height is 180. weight is 90 Kilograms.
# 89
# patient age is 64. gender is Female.  height is 160. weight is 68 Kilograms.
# 90
# patient age is 65. gender is Male.  height is 160. weight is 68 Kilograms.
# 91
# patient age is 54. gender is Female.  height is unavailable.  weight is unavailable.
# 92
# patient age is 62. gender is Male.  height is unavailable.  weight is unavailable.
# 93
# patient age is 46. gender is Male.  height is unavailable.  weight is unavailable.
# 94
# patient age is 51. gender is Female.  height is unavailable.  weight is unavailable.
# 95
# patient age is 52. gender is Male.  height is unavailable.  weight is unavailable.
# 96
# patient age is 69. gender is Female.  height is 170. weight is 80 Kilograms.
# 97
# patient age is 42. gender is Male.  height is 176. weight is 110 Kilograms.
# 98
# patient age is 88. gender is Male.  height is 180. weight is 90 Kilograms.
# 99
# patient age is 62. gender is Female.  height is 156. weight is 78 Kilograms.
# 100
# patient age is 28. gender is Male.  height is 190. weight is 105 Kilograms.
# 101
# patient age is 30. gender is Female.  height is unavailable.  weight is unavailable.
# 102
# patient age is 80. gender is Female.  height is 165. weight is 75 Kilograms.
# 103
# patient age is 30. gender is Male.  height is 172. weight is 75 Kilograms.
# 104
# patient age is 44. gender is Female.  height is 155. weight is 50 Kilograms.
# 105
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 106
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 107
# patient age is 64. gender is Female.  height is unavailable.  weight is unavailable.
# 108
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 109
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 110
# patient age is 47. gender is Male.  height is 162. weight is 71 Kilograms.
# 111
# patient age is 59. gender is Female.  height is 155. weight is 50 Kilograms.
# 112
# patient age is 59. gender is Female.  height is unavailable.  weight is unavailable.
# 113
# patient age is 68. gender is Male.  height is unavailable.  weight is unavailable.
# 114
# patient age is 86. gender is Male.  height is unavailable.  weight is unavailable.
# 115
# patient age is 36. gender is Male.  height is 167. weight is 110 Kilograms.
# 116
# patient age is 36. gender is Female.  height is 168. weight is 100 Kilograms.
# 117
# patient age is 43. gender is Male.  height is unavailable.  weight is unavailable.
# 118
# patient age is 62. gender is Female.  height is unavailable.  weight is unavailable.
# 119
# patient age is 83. gender is Male.  height is unavailable.  weight is unavailable.
# 120
# patient age is 35. gender is Male.  height is unavailable.  weight is unavailable.
# 121
# patient age is 51. gender is Male.  height is 170. weight is 80 Kilograms.
# 122
# patient age is 58. gender is Female.  height is 159. weight is 99 Kilograms.
# 123
# patient age is 50. gender is Female.  height is 160. weight is 65 Kilograms.
# 124
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 125
# patient age is 80. gender is Female.  height is 155. weight is 88 Kilograms.
# 126
# patient age is 90. gender is Male.  height is unavailable.  weight is unavailable.
# 127
# patient age is 44. gender is Male.  height is unavailable.  weight is unavailable.
# 128
# patient age is 66. gender is Male.  height is 170. weight is 110 Kilograms.
# 129
# patient age is 58. gender is Female.  height is unavailable.  weight is unavailable.
# 130
# patient age is 87. gender is Male.  height is 170. weight is 79 Kilograms.
# 131
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 132
# patient age is 86. gender is Male.  height is unavailable.  weight is unavailable.
# 133
# patient age is 86. gender is Male.  height is unavailable.  weight is unavailable.
# 134
# patient age is 94. gender is Male.  height is unavailable.  weight is unavailable.
# 135
# patient age is 88. gender is Male.  height is unavailable.  weight is unavailable.
# 136
# patient age is 83. gender is Female.  height is 170. weight is 70 Kilograms.
# 137
# patient age is 38. gender is Female.  height is 160. weight is 65 Kilograms.
# 138
# patient age is 34. gender is Male.  height is 180. weight is 78 Kilograms.
# 139
# patient age is 61. gender is Male.  height is 163. weight is 60 Kilograms.
# 140
# patient age is 71. gender is Female.  height is 168. weight is 70 Kilograms.
# 141
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 142
# patient age is 48. gender is Male.  height is 170. weight is 70 Kilograms.
# 143
# patient age is 64. gender is Female.  height is 160. weight is 75 Kilograms.
# 144
# patient age is 27. gender is Male.  height is 178. weight is 96 Kilograms.
# 145
# patient age is 44. gender is Female.  height is 170. weight is 95 Kilograms.
# 146
# patient age is 33. gender is Male.  height is 177. weight is 72 Kilograms.
# 147
# patient age is 37. gender is Male.  height is 150. weight is 67 Kilograms.
# 148
# patient age is 36. gender is Male.  height is 190. weight is 100 Kilograms.
# 149
# patient age is 80. gender is Male.  height is 175. weight is 75 Kilograms.
# 150
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 151
# patient age is 42. gender is Male.  height is 175. weight is 75 Kilograms.
# 152
# patient age is 79. gender is Female.  height is unavailable.  weight is unavailable.
# 153
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 154
# patient age is 37. gender is Male.  height is unavailable.  weight is unavailable.
# 155
# patient age is 55. gender is Female.  height is unavailable.  weight is unavailable.
# 156
# patient age is 28. gender is Male.  height is unavailable.  weight is unavailable.
# 157
# patient age is 36. gender is Female.  height is 163. weight is 68 Kilograms.
# 158
# patient age is 47. gender is Female.  height is 171. weight is 82 Kilograms.
# 159
# patient age is 34. gender is Female.  height is 165. weight is 83 Kilograms.
# 160
# patient age is 50. gender is Male.  height is 181. weight is 84 Kilograms.
# 161
# patient age is 72. gender is Male.  height is 176. weight is 84 Kilograms.
# 162
# patient age is 69. gender is Female.  height is unavailable.  weight is unavailable.
# 163
# patient age is 67. gender is Male.  height is 176. weight is 80 Kilograms.
# 164
# patient age is 47. gender is Female.  height is unavailable.  weight is unavailable.
# 165
# patient age is 51. gender is Male.  height is unavailable.  weight is unavailable.
# 166
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 167
# patient age is 82. gender is Male.  height is unavailable.  weight is unavailable.
# 168
# patient age is 58. gender is Male.  height is 165. weight is 55 Kilograms.
# 169
# patient age is 59. gender is Male.  height is unavailable.  weight is unavailable.
# 170
# patient age is 76. gender is Male.  height is 180. weight is 96 Kilograms.
# 171
# patient age is 51. gender is Male.  height is 186. weight is 116 Kilograms.
# 172
# patient age is 72. gender is Male.  height is 165. weight is 60 Kilograms.
# 173
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 174
# patient age is 89. gender is Female.  height is unavailable.  weight is unavailable.
# 175
# patient age is 78. gender is Male.  height is unavailable.  weight is unavailable.
# 176
# patient age is 62. gender is Female.  height is unavailable. weight is 70 Kilograms.
# 177
# patient age is 24. gender is Male.  height is unavailable.  weight is unavailable.
# 178
# patient age is 42. gender is Male.  height is 170. weight is 80 Kilograms.
# 179
# patient age is 79. gender is Male.  height is 170. weight is 68 Kilograms.
# 180
# patient age is 44. gender is Female.  height is unavailable.  weight is unavailable.
# 181
# patient age is 36. gender is Male.  height is 170. weight is 88 Kilograms.
# 182
# patient age is 61. gender is Female.  height is 153. weight is 105 Kilograms.
# 183
# patient age is 44. gender is Female.  height is unavailable.  weight is unavailable.
# 184
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 185
# patient age is 75. gender is Female.  height is 160. weight is 50 Kilograms.
# 186
# patient age is 94. gender is Female.  height is unavailable.  weight is unavailable.
# 187
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 188
# patient age is 82. gender is Male.  height is unavailable. weight is 70 Kilograms.
# 189
# patient age is 71. gender is Female.  height is unavailable.  weight is unavailable.
# 190
# patient age is 83. gender is Male.  height is 165. weight is 66 Kilograms.
# 191
# patient age is 68. gender is Male.  height is 175. weight is 80 Kilograms.
# 192
# patient age is 60. gender is Male.  height is unavailable.  weight is unavailable.
# 193
# patient age is 80. gender is Male.  height is unavailable.  weight is unavailable.
# 194
# patient age is 38. gender is Female.  height is 160. weight is 110 Kilograms.
# 195
# patient age is 85. gender is Male.  height is unavailable.  weight is unavailable.
# 196
# patient age is 53. gender is Female.  height is unavailable.  weight is unavailable.
# 197
# patient age is 56. gender is Female.  height is unavailable.  weight is unavailable.
# 198
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 199
# patient age is 34. gender is Male.  height is unavailable.  weight is unavailable.
# 200
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 201
# patient age is 49. gender is Female.  height is unavailable.  weight is unavailable.
# 202
# patient age is 85. gender is Female.  height is unavailable.  weight is unavailable.
# 203
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 204
# patient age is 38. gender is Female.  height is unavailable.  weight is unavailable.
# 205
# patient age is 32. gender is Male.  height is unavailable.  weight is unavailable.
# 206
# patient age is 37. gender is Female.  height is unavailable.  weight is unavailable.
# 207
# patient age is 45. gender is Female.  height is unavailable.  weight is unavailable.
# 208
# patient age is 51. gender is Female.  height is unavailable.  weight is unavailable.
# 209
# patient age is 39. gender is Female.  height is 156. weight is 80 Kilograms.
# 210
# patient age is 33. gender is Male.  height is 189. weight is 85 Kilograms.
# 211
# patient age is 55. gender is Female.  height is 165. weight is 70 Kilograms.
# 212
# patient age is 44. gender is Female.  height is unavailable.  weight is unavailable.
# 213
# patient age is 79. gender is Female.  height is unavailable.  weight is unavailable.
# 214
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 215
# patient age is 46. gender is Female.  height is unavailable.  weight is unavailable.
# 216
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 217
# patient age is 89. gender is Female.  height is unavailable.  weight is unavailable.
# 218
# patient age is 35. gender is Male.  height is 175. weight is 90 Kilograms.
# 219
# patient age is 54. gender is Male.  height is 170. weight is 80 Kilograms.
# 220
# patient age is 55. gender is Male.  height is 186. weight is 84 Kilograms.
# 221
# patient age is 66. gender is Female.  height is unavailable.  weight is unavailable.
# 222
# patient age is 52. gender is Female.  height is unavailable.  weight is unavailable.
# 223
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 224
# patient age is 58. gender is Female.  height is 155. weight is 114 Kilograms.
# 225
# patient age is 73. gender is Female.  height is unavailable.  weight is unavailable.
# 226
# patient age is 50. gender is Female.  height is unavailable.  weight is unavailable.
# 227
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 228
# patient age is 38. gender is Male.  height is unavailable.  weight is unavailable.
# 229
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 230
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 231
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 232
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 233
# patient age is 51. gender is Female.  height is unavailable.  weight is unavailable.
# 234
# patient age is 37. gender is Female.  height is unavailable.  weight is unavailable.
# 235
# patient age is 44. gender is Male.  height is unavailable.  weight is unavailable.
# 236
# patient age is 58. gender is Male.  height is unavailable.  weight is unavailable.
# 237
# patient age is 58. gender is Male.  height is unavailable.  weight is unavailable.
# 238
# patient age is 59. gender is Female.  height is unavailable.  weight is unavailable.
# 239
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 240
# patient age is 78. gender is Female.  height is unavailable.  weight is unavailable.
# 241
# patient age is 41. gender is Male.  height is unavailable.  weight is unavailable.
# 242
# patient age is 51. gender is Male.  height is unavailable.  weight is unavailable.
# 243
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 244
# patient age is 72. gender is Female.  height is unavailable.  weight is unavailable.
# 245
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 246
# patient age is 42. gender is Male.  height is unavailable.  weight is unavailable.
# 247
# patient age is 85. gender is Female.  height is 160. weight is 60 Kilograms.
# 248
# patient age is 22. gender is Female.  height is 155. weight is 70 Kilograms.
# 249
# patient age is 32. gender is Male.  height is unavailable.  weight is unavailable.
# 250
# patient age is 31. gender is Male.  height is 162. weight is 88 Kilograms.
# 251
# patient age is 55. gender is Male.  height is unavailable.  weight is unavailable.
# 252
# patient age is 66. gender is Female.  height is unavailable.  weight is unavailable.
# 253
# patient age is 29. gender is Female.  height is unavailable.  weight is unavailable.
# 254
# patient age is 69. gender is Female.  height is unavailable.  weight is unavailable.
# 255
# patient age is 86. gender is Female.  height is unavailable.  weight is unavailable.
# 256
# patient age is 85. gender is Female.  height is unavailable.  weight is unavailable.
# 257
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 258
# patient age is 77. gender is Female.  height is unavailable.  weight is unavailable.
# 259
# patient age is 54. gender is Male.  height is 175. weight is 78 Kilograms.
# 260
# patient age is 53. gender is Female.  height is unavailable.  weight is unavailable.
# 261
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 262
# patient age is 60. gender is Female.  height is 165. weight is 72 Kilograms.
# 263
# patient age is 51. gender is Male.  height is 170. weight is 67 Kilograms.
# 264
# patient age is 36. gender is Male.  height is unavailable.  weight is unavailable.
# 265
# patient age is 36. gender is Female.  height is unavailable.  weight is unavailable.
# 266
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 267
# patient age is 27. gender is Male.  height is unavailable.  weight is unavailable.
# 268
# patient age is 50. gender is Male.  height is 163. weight is 59 Kilograms.
# 269
# patient age is 57. gender is Male.  height is 175. weight is 80 Kilograms.
# 270
# patient age is 47. gender is Female.  height is 166. weight is 78 Kilograms.
# 271
# patient age is 55. gender is Male.  height is unavailable.  weight is unavailable.
# 272
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 273
# patient age is 83. gender is Female.  height is 164. weight is 59 Kilograms.
# 274
# patient age is 68. gender is Female.  height is 160. weight is 60 Kilograms.
# 275
# patient age is 45. gender is Male.  height is 170. weight is 75 Kilograms.
# 276
# patient age is 72. gender is Male.  height is 179. weight is 90 Kilograms.
# 277
# patient age is 61. gender is Male.  height is 170. weight is 105 Kilograms.
# 278
# patient age is 76. gender is Female.  height is 156. weight is 80 Kilograms.
# 279
# patient age is 41. gender is Male.  height is 155. weight is 75 Kilograms.
# 280
# patient age is 59. gender is Female.  height is 159. weight is 70 Kilograms.
# 281
# patient age is 64. gender is Female.  height is 150. weight is 58 Kilograms.
# 282
# patient age is 53. gender is Male.  height is 186. weight is 90 Kilograms.
# 283
# patient age is 71. gender is Female.  height is 160. weight is 100 Kilograms.
# 284
# patient age is 31. gender is Male.  height is 180. weight is 70 Kilograms.
# 285
# patient age is 26. gender is Female.  height is 165. weight is 70 Kilograms.
# 286
# patient age is 51. gender is Male.  height is 174. weight is 82 Kilograms.
# 287
# patient age is 80. gender is Male.  height is unavailable.  weight is unavailable.
# 288
# patient age is 60. gender is Male.  height is 178. weight is 79 Kilograms.
# 289
# patient age is 46. gender is Female.  height is 156. weight is 95 Kilograms.
# 290
# patient age is 54. gender is Male.  height is 180. weight is 80 Kilograms.
# 291
# patient age is 30. gender is Male.  height is 168. weight is 109 Kilograms.
# 292
# patient age is 44. gender is Female.  height is 173. weight is 73 Kilograms.
# 293
# patient age is 41. gender is Male.  height is 170. weight is 70 Kilograms.
# 294
# patient age is 48. gender is Female.  height is 160. weight is 70 Kilograms.
# 295
# patient age is 44. gender is Female.  height is 165. weight is 70 Kilograms.
# 296
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 297
# patient age is 38. gender is Male.  height is 170. weight is 84 Kilograms.
# 298
# patient age is 45. gender is Female.  height is 157. weight is 65 Kilograms.
# 299
# patient age is 49. gender is Male.  height is 168. weight is 65 Kilograms.
# 300
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 301
# patient age is 60. gender is Female.  height is 165. weight is 70 Kilograms.
# 302
# patient age is 84. gender is Female.  height is 165. weight is 80 Kilograms.
# 303
# patient age is 47. gender is Female.  height is 160. weight is 75 Kilograms.
# 304
# patient age is 48. gender is Female.  height is unavailable.  weight is unavailable.
# 305
# patient age is 74. gender is Female.  height is 160. weight is 75 Kilograms.
# 306
# patient age is 55. gender is Male.  height is unavailable.  weight is unavailable.
# 307
# patient age is 48. gender is Male.  height is 159. weight is 70 Kilograms.
# 308
# patient age is 49. gender is Female.  height is 170. weight is 72 Kilograms.
# 309
# patient age is 38. gender is Male.  height is 185. weight is 94 Kilograms.
# 310
# patient age is 38. gender is Male.  height is 180. weight is 94 Kilograms.
# 311
# patient age is 37. gender is Female.  height is 160. weight is 70 Kilograms.
# 312
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 313
# patient age is 50. gender is Female.  height is 150. weight is 115 Kilograms.
# 314
# patient age is 53. gender is Female.  height is 160. weight is 60 Kilograms.
# 315
# patient age is 47. gender is Female.  height is unavailable.  weight is unavailable.
# 316
# patient age is 23. gender is Male.  height is 180. weight is 105 Kilograms.
# 317
# patient age is 40. gender is Male.  height is 178. weight is 82 Kilograms.
# 318
# patient age is 65. gender is Female.  height is 163. weight is 90 Kilograms.
# 319
# patient age is 33. gender is Female.  height is 158. weight is 75 Kilograms.
# 320
# patient age is 62. gender is Male.  height is 165. weight is 74 Kilograms.
# 321
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 322
# patient age is 38. gender is Female.  height is 164. weight is 90 Kilograms.
# 323
# patient age is 48. gender is Male.  height is 188. weight is 125 Kilograms.
# 324
# patient age is 40. gender is Female.  height is unavailable.  weight is unavailable.
# 325
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 326
# patient age is 58. gender is Female.  height is 160. weight is 115 Kilograms.
# 327
# patient age is 60. gender is Male.  height is 168. weight is 90 Kilograms.
# 328
# patient age is 48. gender is Female.  height is 170. weight is 78 Kilograms.
# 329
# patient age is 51. gender is Male.  height is unavailable.  weight is unavailable.
# 330
# patient age is 43. gender is Female.  height is unavailable.  weight is unavailable.
# 331
# patient age is 42. gender is Female.  height is 160. weight is 70 Kilograms.
# 332
# patient age is 18. gender is Female.  height is unavailable.  weight is unavailable.
# 333
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 334
# patient age is 83. gender is Male.  height is 175. weight is 80 Kilograms.
# 335
# patient age is 58. gender is Male.  height is 165. weight is 70 Kilograms.
# 336
# patient age is 27. gender is Female.  height is 165. weight is 75 Kilograms.
# 337
# patient age is 41. gender is Female.  height is 172. weight is 70 Kilograms.
# 338
# patient age is 66. gender is Male.  height is unavailable.  weight is unavailable.
# 339
# patient age is 42. gender is Male.  height is unavailable. weight is 72 Kilograms.
# 340
# patient age is 45. gender is Male.  height is 178. weight is 78 Kilograms.
# 341
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 342
# patient age is 65. gender is Female.  height is 157. weight is 70 Kilograms.
# 343
# patient age is 36. gender is Male.  height is 175. weight is 79 Kilograms.
# 344
# patient age is 37. gender is Male.  height is unavailable.  weight is unavailable.
# 345
# patient age is 41. gender is Female.  height is 160. weight is 79 Kilograms.
# 346
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 347
# patient age is 37. gender is Male.  height is 178. weight is 98 Kilograms.
# 348
# patient age is 53. gender is Male.  height is 170. weight is 80 Kilograms.
# 349
# patient age is 44. gender is Male.  height is 178. weight is 114 Kilograms.
# 350
# patient age is 48. gender is Male.  height is 182. weight is 98 Kilograms.
# 351
# patient age is 50. gender is Female.  height is unavailable.  weight is unavailable.
# 352
# patient age is 48. gender is Female.  height is 160. weight is 62 Kilograms.
# 353
# patient age is 62. gender is Female.  height is unavailable.  weight is unavailable.
# 354
# patient age is 55. gender is Male.  height is 168. weight is 70 Kilograms.
# 355
# patient age is 53. gender is Female.  height is 158. weight is 77 Kilograms.
# 356
# patient age is 65. gender is Female.  height is unavailable.  weight is unavailable.
# 357
# patient age is 52. gender is Female.  height is 170. weight is 92 Kilograms.
# 358
# patient age is 54. gender is Male.  height is 175. weight is 80 Kilograms.
# 359
# patient age is 30. gender is Female.  height is 160. weight is 100 Kilograms.
# 360
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 361
# patient age is 44. gender is Female.  height is 170. weight is 60 Kilograms.
# 362
# patient age is 64. gender is Female.  height is unavailable.  weight is unavailable.
# 363
# patient age is 67. gender is Female.  height is 156. weight is 68 Kilograms.
# 364
# patient age is 89. gender is Male.  height is unavailable.  weight is unavailable.
# 365
# patient age is 69. gender is Female.  height is unavailable.  weight is unavailable.
# 366
# patient age is 58. gender is Male.  height is unavailable.  weight is unavailable.
# 367
# patient age is 43. gender is Female.  height is unavailable.  weight is unavailable.
# 368
# patient age is 58. gender is Female.  height is 164. weight is 70 Kilograms.
# 369
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 370
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 371
# patient age is 20. gender is Female.  height is unavailable.  weight is unavailable.
# 372
# patient age is 81. gender is Male.  height is unavailable.  weight is unavailable.
# 373
# patient age is 39. gender is Male.  height is unavailable.  weight is unavailable.
# 374
# patient age is 53. gender is Female.  height is unavailable.  weight is unavailable.
# 375
# patient age is 25. gender is Male.  height is unavailable.  weight is unavailable.
# 376
# patient age is 53. gender is Male.  height is 179. weight is 95 Kilograms.
# 377
# patient age is 48. gender is Female.  height is 163. weight is 89 Kilograms.
# 378
# patient age is 82. gender is Female.  height is 160. weight is 70 Kilograms.
# 379
# patient age is 49. gender is Male.  height is 172. weight is 76 Kilograms.
# 380
# patient age is 45. gender is Female.  height is 156. weight is 70 Kilograms.
# 381
# patient age is 51. gender is Male.  height is 173. weight is 85 Kilograms.
# 382
# patient age is 83. gender is Female.  height is unavailable.  weight is unavailable.
# 383
# patient age is 40. gender is Male.  height is unavailable.  weight is unavailable.
# 384
# patient age is 55. gender is Male.  height is 180. weight is 70 Kilograms.
# 385
# patient age is 41. gender is Male.  height is unavailable.  weight is unavailable.
# 386
# patient age is 62. gender is Female.  height is 166. weight is 68 Kilograms.
# 387
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 388
# patient age is 44. gender is Female.  height is 168. weight is 72 Kilograms.
# 389
# patient age is 80. gender is Female.  height is 170. weight is 75 Kilograms.
# 390
# patient age is 53. gender is Female.  height is unavailable.  weight is unavailable.
# 391
# patient age is 87. gender is Male.  height is 158. weight is 60 Kilograms.
# 392
# patient age is 59. gender is Female.  height is 168. weight is 67 Kilograms.
# 393
# patient age is 73. gender is Female.  height is unavailable.  weight is unavailable.
# 394
# patient age is 55. gender is Male.  height is 180. weight is 120 Kilograms.
# 395
# patient age is 35. gender is Male.  height is 164. weight is 82 Kilograms.
# 396
# patient age is 36. gender is Female.  height is 162. weight is 75 Kilograms.
# 397
# patient age is 26. gender is Male.  height is 178. weight is 82 Kilograms.
# 398
# patient age is 52. gender is Male.  height is 172. weight is 84 Kilograms.
# 399
# patient age is 37. gender is Female.  height is 172. weight is 79 Kilograms.
# 400
# patient age is 70. gender is Female.  height is unavailable.  weight is unavailable.
# 401
# patient age is 39. gender is Male.  height is unavailable.  weight is unavailable.
# 402
# patient age is 41. gender is Male.  height is 180. weight is 94 Kilograms.
# 403
# patient age is 49. gender is Female.  height is 160. weight is 59 Kilograms.
# 404
# patient age is 48. gender is Female.  height is 160. weight is 75 Kilograms.
# 405
# patient age is 48. gender is Male.  height is 170. weight is 89 Kilograms.
# 406
# patient age is 79. gender is Female.  height is 160. weight is 80 Kilograms.
# 407
# patient age is 38. gender is Male.  height is 160. weight is 67 Kilograms.
# 408
# patient age is 36. gender is Female.  height is 162. weight is 65 Kilograms.
# 409
# patient age is 54. gender is Male.  height is 175. weight is 80 Kilograms.
# 410
# patient age is 46. gender is Female.  height is 150. weight is 60 Kilograms.
# 411
# patient age is 81. gender is Male.  height is 165. weight is 90 Kilograms.
# 412
# patient age is 82. gender is Male.  height is 185. weight is 80 Kilograms.
# 413
# patient age is 83. gender is Male.  height is unavailable.  weight is unavailable.
# 414
# patient age is 72. gender is Female.  height is 162. weight is 74 Kilograms.
# 415
# patient age is 94. gender is Male.  height is 172. weight is 95 Kilograms.
# 416
# patient age is 60. gender is Male.  height is 175. weight is 80 Kilograms.
# 417
# patient age is 54. gender is Female.  height is unavailable.  weight is unavailable.
# 418
# patient age is 76. gender is Female.  height is 148. weight is 54 Kilograms.
# 419
# patient age is 75. gender is Male.  height is unavailable.  weight is unavailable.
# 420
# patient age is 27. gender is Female.  height is 165. weight is 63 Kilograms.
# 421
# patient age is 34. gender is Female.  height is 160. weight is 70 Kilograms.
# 422
# patient age is 42. gender is Female.  height is unavailable.  weight is unavailable.
# 423
# patient age is 44. gender is Male.  height is unavailable.  weight is unavailable.
# 424
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 425
# patient age is 67. gender is Male.  height is 170. weight is 82 Kilograms.
# 426
# patient age is 87. gender is Female.  height is unavailable.  weight is unavailable.
# 427
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 428
# patient age is 84. gender is Male.  height is unavailable.  weight is unavailable.
# 429
# patient age is 45. gender is Female.  height is 168. weight is 80 Kilograms.
# 430
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 431
# patient age is 70. gender is Female.  height is 160. weight is 65 Kilograms.
# 432
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 433
# patient age is 32. gender is Male.  height is 170. weight is 75 Kilograms.
# 434
# patient age is 70. gender is Male.  height is 155. weight is 50 Kilograms.
# 435
# patient age is 79. gender is Female.  height is 150. weight is 50 Kilograms.
# 436
# patient age is 49. gender is Female.  height is 157. weight is 52 Kilograms.
# 437
# patient age is 52. gender is Male.  height is 178. weight is 78 Kilograms.
# 438
# patient age is 84. gender is Female.  height is 169. weight is 55 Kilograms.
# 439
# patient age is 49. gender is Female.  height is unavailable.  weight is unavailable.
# 440
# patient age is 69. gender is Male.  height is unavailable.  weight is unavailable.
# 441
# patient age is 65. gender is Female.  height is unavailable.  weight is unavailable.
# 442
# patient age is 56. gender is Female.  height is 162. weight is 55 Kilograms.
# 443
# patient age is 71. gender is Female.  height is 168. weight is 58 Kilograms.
# 444
# patient age is 69. gender is Male.  height is unavailable.  weight is unavailable.
# 445
# patient age is 63. gender is Female.  height is 160. weight is 65 Kilograms.
# 446
# patient age is 67. gender is Female.  height is unavailable.  weight is unavailable.
# 447
# patient age is 63. gender is Male.  height is 166. weight is 72 Kilograms.
# 448
# patient age is 40. gender is Male.  height is 180. weight is 100 Kilograms.
# 449
# patient age is 31. gender is Female.  height is 155. weight is 68 Kilograms.
# 450
# patient age is 87. gender is Female.  height is 158. weight is 71 Kilograms.
# 451
# patient age is 88. gender is Male.  height is unavailable.  weight is unavailable.
# 452
# patient age is 46. gender is Female.  height is 165. weight is 126 Kilograms.
# 453
# patient age is 37. gender is Male.  height is unavailable.  weight is unavailable.
# 454
# patient age is 37. gender is Female.  height is unavailable.  weight is unavailable.
# 455
# patient age is 37. gender is Female.  height is unavailable.  weight is unavailable.
# 456
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 457
# patient age is 59. gender is Male.  height is 155. weight is 93 Kilograms.
# 458
# patient age is 80. gender is Female.  height is unavailable.  weight is unavailable.
# 459
# patient age is 62. gender is Female.  height is 152. weight is 58 Kilograms.
# 460
# patient age is 53. gender is Female.  height is 155. weight is 100 Kilograms.
# 461
# patient age is 50. gender is Female.  height is unavailable.  weight is unavailable.
# 462
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 463
# patient age is 51. gender is Female.  height is 155. weight is 70 Kilograms.
# 464
# patient age is 92. gender is Male.  height is unavailable.  weight is unavailable.
# 465
# patient age is 61. gender is Male.  height is 165. weight is 75 Kilograms.
# 466
# patient age is 54. gender is Female.  height is 160. weight is 90 Kilograms.
# 467
# patient age is 84. gender is Male.  height is 180. weight is 85 Kilograms.
# 468
# patient age is 49. gender is Female.  height is 174. weight is 70 Kilograms.
# 469
# patient age is 65. gender is Male.  height is 150. weight is 85 Kilograms.
# 470
# patient age is 82. gender is Male.  height is 185. weight is 80 Kilograms.
# 471
# patient age is 26. gender is Male.  height is 144. weight is 35 Kilograms.
# 472
# patient age is 80. gender is Male.  height is unavailable.  weight is unavailable.
# 473
# patient age is 19. gender is Male.  height is unavailable.  weight is unavailable.
# 474
# patient age is 59. gender is Female.  height is unavailable.  weight is unavailable.
# 475
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 476
# patient age is 88. gender is Male.  height is 175. weight is 65 Kilograms.
# 477
# patient age is 80. gender is Male.  height is 170. weight is 70 Kilograms.
# 478
# patient age is 40. gender is Female.  height is 160. weight is 76 Kilograms.
# 479
# patient age is 59. gender is Female.  height is 165. weight is 90 Kilograms.
# 480
# patient age is 82. gender is Male.  height is 168. weight is 70 Kilograms.
# 481
# patient age is 51. gender is Female.  height is 165. weight is 67 Kilograms.
# 482
# patient age is 68. gender is Male.  height is 170. weight is 65 Kilograms.
# 483
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 484
# patient age is 33. gender is Female.  height is 155. weight is 68 Kilograms.
# 485
# patient age is 90. gender is Female.  height is unavailable.  weight is unavailable.
# 486
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 487
# patient age is 63. gender is Male.  height is 165. weight is 65 Kilograms.
# 488
# patient age is 47. gender is Male.  height is 178. weight is 80 Kilograms.
# 489
# patient age is 67. gender is Female.  height is 163. weight is 80 Kilograms.
# 490
# patient age is 89. gender is Male.  height is 180. weight is 70 Kilograms.
# 491
# patient age is 89. gender is Male.  height is 180. weight is 70 Kilograms.
# 492
# patient age is 97. gender is Male.  height is 160. weight is 67 Kilograms.
# 493
# patient age is 63. gender is Female.  height is 153. weight is 50 Kilograms.
# 494
# patient age is 57. gender is Male.  height is 167. weight is 95 Kilograms.
# 495
# patient age is 21. gender is Male.  height is unavailable.  weight is unavailable.
# 496
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 497
# patient age is 69. gender is Female.  height is 175. weight is 75 Kilograms.
# 498
# patient age is 57. gender is Female.  height is 165. weight is 84 Kilograms.
# 499
# patient age is 21. gender is Female.  height is 160. weight is 52 Kilograms.
# 500
# patient age is 21. gender is Male.  height is 175. weight is 60 Kilograms.
# 501
# patient age is 71. gender is Female.  height is 163. weight is 95 Kilograms.
# 502
# patient age is 20. gender is Male.  height is unavailable.  weight is unavailable.
# 503
# patient age is 82. gender is Male.  height is 160. weight is 50 Kilograms.
# 504
# patient age is 60. gender is Male.  height is unavailable.  weight is unavailable.
# 505
# patient age is 82. gender is Female.  height is unavailable.  weight is unavailable.
# 506
# patient age is 73. gender is Male.  height is 169. weight is 79 Kilograms.
# 507
# patient age is 34. gender is Male.  height is unavailable.  weight is unavailable.
# 508
# patient age is 54. gender is Male.  height is unavailable.  weight is unavailable.
# 509
# patient age is 69. gender is Male.  height is unavailable.  weight is unavailable.
# 510
# patient age is 80. gender is Male.  height is unavailable.  weight is unavailable.
# 511
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 512
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 513
# patient age is 40. gender is Male.  height is 172. weight is 72 Kilograms.
# 514
# patient age is 67. gender is Female.  height is 170. weight is 70 Kilograms.
# 515
# patient age is 78. gender is Male.  height is unavailable.  weight is unavailable.
# 516
# patient age is 37. gender is Female.  height is 158. weight is 59 Kilograms.
# 517
# patient age is 98. gender is Male.  height is unavailable.  weight is unavailable.
# 518
# patient age is 82. gender is Male.  height is unavailable.  weight is unavailable.
# 519
# patient age is 80. gender is Female.  height is 160. weight is 90 Kilograms.
# 520
# patient age is 52. gender is Male.  height is 175. weight is 95 Kilograms.
# 521
# patient age is 46. gender is Female.  height is unavailable.  weight is unavailable.
# 522
# patient age is 49. gender is Female.  height is 168. weight is 74 Kilograms.
# 523
# patient age is 75. gender is Female.  height is unavailable.  weight is unavailable.
# 524
# patient age is 64. gender is Male.  height is 180. weight is 60 Kilograms.
# 525
# patient age is 83. gender is Female.  height is 155. weight is 70 Kilograms.
# 526
# patient age is 49. gender is Male.  height is 170. weight is 85 Kilograms.
# 527
# patient age is 79. gender is Female.  height is 140. weight is 43 Kilograms.
# 528
# patient age is 56. gender is Female.  height is 159. weight is 71 Kilograms.
# 529
# patient age is 54. gender is Female.  height is unavailable.  weight is unavailable.
# 530
# patient age is 77. gender is Female.  height is unavailable.  weight is unavailable.
# 531
# patient age is 72. gender is Female.  height is unavailable.  weight is unavailable.
# 532
# patient age is 44. gender is Female.  height is unavailable.  weight is unavailable.
# 533
# patient age is 51. gender is Female.  height is unavailable.  weight is unavailable.
# 534
# patient age is 44. gender is Male.  height is unavailable.  weight is unavailable.
# 535
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 536
# patient age is 62. gender is Female.  height is unavailable.  weight is unavailable.
# 537
# patient age is 62. gender is Male.  height is 165. weight is 85 Kilograms.
# 538
# patient age is 33. gender is Female.  height is 163. weight is 53 Kilograms.
# 539
# patient age is 69. gender is Female.  height is 180. weight is 85 Kilograms.
# 540
# patient age is 67. gender is Male.  height is 175. weight is 90 Kilograms.
# 541
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 542
# patient age is 66. gender is Male.  height is 170. weight is 70 Kilograms.
# 543
# patient age is 41. gender is Male.  height is unavailable. weight is 90 Kilograms.
# 544
# patient age is 93. gender is Female.  height is unavailable.  weight is unavailable.
# 545
# patient age is 31. gender is Female.  height is 168. weight is 68 Kilograms.
# 546
# patient age is 70. gender is Male.  height is 170. weight is 75 Kilograms.
# 547
# patient age is 75. gender is Male.  height is 175. weight is 80 Kilograms.
# 548
# patient age is 88. gender is Female.  height is 165. weight is 95 Kilograms.
# 549
# patient age is 46. gender is Female.  height is unavailable. weight is 80 Kilograms.
# 550
# patient age is 34. gender is Female.  height is 168. weight is 85 Kilograms.
# 551
# patient age is 29. gender is Male.  height is 168. weight is 44 Kilograms.
# 552
# patient age is 64. gender is Female.  height is unavailable.  weight is unavailable.
# 553
# patient age is 55. gender is Male.  height is 169. weight is 85 Kilograms.
# 554
# patient age is 51. gender is Female.  height is 150. weight is 72 Kilograms.
# 555
# patient age is 51. gender is Female.  height is 163. weight is 75 Kilograms.
# 556
# patient age is 22. gender is Male.  height is unavailable.  weight is unavailable.
# 557
# patient age is 62. gender is Female.  height is unavailable.  weight is unavailable.
# 558
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 559
# patient age is 18. gender is Male.  height is unavailable.  weight is unavailable.
# 560
# patient age is 84. gender is Male.  height is unavailable.  weight is unavailable.
# 561
# patient age is 54. gender is Male.  height is 168. weight is 72 Kilograms.
# 562
# patient age is 51. gender is Male.  height is 176. weight is 85 Kilograms.
# 563
# patient age is 82. gender is Female.  height is 175. weight is 86 Kilograms.
# 564
# patient age is 30. gender is Male.  height is 189. weight is 89 Kilograms.
# 565
# patient age is 42. gender is Female.  height is unavailable.  weight is unavailable.
# 566
# patient age is 22. gender is Female.  height is 165. weight is 53 Kilograms.
# 567
# patient age is 63. gender is Male.  height is 175. weight is 63 Kilograms.
# 568
# ...
# 8953
# patient age is 70. gender is Female.  height is unavailable.  weight is unavailable.
# 8954
# patient age is 91. gender is Male.  height is unavailable.  weight is unavailable.
# 8955
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 8956
# patient age is 52. gender is Male.  height is unavailable.  weight is unavailable.
# 8957
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 8958
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 8959
# patient age is 50. gender is Female.  height is unavailable.  weight is unavailable.
# 8960
# patient age is 81. gender is Female.  height is unavailable.  weight is unavailable.
# 8961
# patient age is 41. gender is Male.  height is unavailable.  weight is unavailable.
# 8962
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 8963
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 8964
# patient age is 88. gender is Male.  height is unavailable.  weight is unavailable.
# 8965
# patient age is 39. gender is Male.  height is unavailable.  weight is unavailable.
# 8966
# patient age is 62. gender is Female.  height is unavailable.  weight is unavailable.
# 8967
# patient age is 42. gender is Male.  height is unavailable.  weight is unavailable.
# 8968
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 8969
# patient age is 31. gender is Female.  height is unavailable.  weight is unavailable.
# 8970
# patient age is 40. gender is Male.  height is unavailable.  weight is unavailable.
# 8971
# patient age is 34. gender is Male.  height is unavailable.  weight is unavailable.
# 8972
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 8973
# patient age is 58. gender is Male.  height is unavailable.  weight is unavailable.
# 8974
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 8975
# patient age is 53. gender is Male.  height is unavailable.  weight is unavailable.
# 8976
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 8977
# patient age is 45. gender is Male.  height is unavailable.  weight is unavailable.
# 8978
# patient age is 42. gender is Male.  height is unavailable.  weight is unavailable.
# 8979
# patient age is 57. gender is Male.  height is unavailable.  weight is unavailable.
# 8980
# patient age is 21. gender is Female.  height is unavailable.  weight is unavailable.
# 8981
# patient age is 74. gender is Female.  height is unavailable.  weight is unavailable.
# 8982
# patient age is 57. gender is Male.  height is unavailable.  weight is unavailable.
# 8983
# patient age is 38. gender is Female.  height is unavailable.  weight is unavailable.
# 8984
# patient age is 46. gender is Male.  height is unavailable.  weight is unavailable.
# 8985
# patient age is 72. gender is Female.  height is unavailable.  weight is unavailable.
# 8986
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 8987
# patient age is 34. gender is Female.  height is unavailable.  weight is unavailable.
# 8988
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 8989
# patient age is 26. gender is Male.  height is unavailable.  weight is unavailable.
# 8990
# patient age is 59. gender is Female.  height is unavailable.  weight is unavailable.
# 8991
# patient age is 71. gender is Female.  height is unavailable.  weight is unavailable.
# 8992
# patient age is 73. gender is Male.  height is unavailable.  weight is unavailable.
# 8993
# patient age is 83. gender is Female.  height is unavailable.  weight is unavailable.
# 8994
# patient age is 76. gender is Male.  height is unavailable.  weight is unavailable.
# 8995
# patient age is 46. gender is Male.  height is unavailable.  weight is unavailable.
# 8996
# patient age is 66. gender is Male.  height is unavailable.  weight is unavailable.
# 8997
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 8998
# patient age is 60. gender is Female.  height is unavailable.  weight is unavailable.
# 8999
# patient age is 32. gender is Female.  height is unavailable.  weight is unavailable.
# 9000
# patient age is 67. gender is Female.  height is unavailable.  weight is unavailable.
# 9001
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 9002
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 9003
# patient age is 23. gender is Male.  height is unavailable.  weight is unavailable.
# 9004
# patient age is 45. gender is Female.  height is unavailable.  weight is unavailable.
# 9005
# patient age is 35. gender is Male.  height is unavailable.  weight is unavailable.
# 9006
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 9007
# patient age is 49. gender is Male.  height is unavailable.  weight is unavailable.
# 9008
# patient age is 84. gender is Male.  height is unavailable.  weight is unavailable.
# 9009
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 9010
# patient age is 88. gender is Female.  height is unavailable.  weight is unavailable.
# 9011
# patient age is 69. gender is Male.  height is unavailable.  weight is unavailable.
# 9012
# patient age is 64. gender is Female.  height is unavailable.  weight is unavailable.
# 9013
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 9014
# patient age is 39. gender is Female.  height is unavailable.  weight is unavailable.
# 9015
# patient age is 60. gender is Female.  height is unavailable.  weight is unavailable.
# 9016
# patient age is 22. gender is Male.  height is unavailable.  weight is unavailable.
# 9017
# patient age is 21. gender is Female.  height is unavailable.  weight is unavailable.
# 9018
# patient age is 47. gender is Female.  height is unavailable.  weight is unavailable.
# 9019
# patient age is 29. gender is Male.  height is unavailable.  weight is unavailable.
# 9020
# patient age is 48. gender is Male.  height is unavailable.  weight is unavailable.
# 9021
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 9022
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 9023
# patient age is 39. gender is Male.  height is unavailable.  weight is unavailable.
# 9024
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 9025
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 9026
# patient age is 50. gender is Male.  height is unavailable.  weight is unavailable.
# 9027
# patient age is 62. gender is Male.  height is unavailable.  weight is unavailable.
# 9028
# patient age is 31. gender is Male.  height is unavailable.  weight is unavailable.
# 9029
# patient age is 34. gender is Male.  height is unavailable.  weight is unavailable.
# 9030
# patient age is 86. gender is Male.  height is unavailable.  weight is unavailable.
# 9031
# patient age is 65. gender is Male.  height is unavailable.  weight is unavailable.
# 9032
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 9033
# patient age is 72. gender is Male.  height is unavailable.  weight is unavailable.
# 9034
# patient age is 52. gender is Female.  height is unavailable.  weight is unavailable.
# 9035
# patient age is 41. gender is Female.  height is unavailable.  weight is unavailable.
# 9036
# patient age is 69. gender is Female.  height is unavailable.  weight is unavailable.
# 9037
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 9038
# patient age is 85. gender is Male.  height is unavailable.  weight is unavailable.
# 9039
# patient age is 61. gender is Female.  height is unavailable.  weight is unavailable.
# 9040
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 9041
# patient age is 29. gender is Male.  height is unavailable.  weight is unavailable.
# 9042
# patient age is 31. gender is Female.  height is unavailable.  weight is unavailable.
# 9043
# patient age is 75. gender is Female.  height is unavailable.  weight is unavailable.
# 9044
# patient age is 53. gender is Female.  height is unavailable.  weight is unavailable.
# 9045
# patient age is 56. gender is Male.  height is unavailable.  weight is unavailable.
# 9046
# patient age is 55. gender is Female.  height is unavailable.  weight is unavailable.
# 9047
# patient age is 44. gender is Male.  height is unavailable.  weight is unavailable.
# 9048
# patient age is 75. gender is Female.  height is unavailable.  weight is unavailable.
# 9049
# patient age is 55. gender is Male.  height is unavailable.  weight is unavailable.
# 9050
# patient age is 71. gender is Female.  height is unavailable.  weight is unavailable.
# 9051
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 9052
# patient age is 24. gender is Male.  height is unavailable.  weight is unavailable.
# 9053
# patient age is 63. gender is Male.  height is unavailable.  weight is unavailable.
# 9054
# patient age is 41. gender is Female.  height is unavailable.  weight is unavailable.
# 9055
# patient age is 81. gender is Male.  height is unavailable.  weight is unavailable.
# 9056
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 9057
# patient age is 95. gender is Female.  height is unavailable.  weight is unavailable.
# 9058
# patient age is 98. gender is Male.  height is unavailable.  weight is unavailable.
# 9059
# patient age is 86. gender is Male.  height is unavailable.  weight is unavailable.
# 9060
# patient age is 55. gender is Male.  height is unavailable.  weight is unavailable.
# 9061
# patient age is 78. gender is Female.  height is unavailable.  weight is unavailable.
# 9062
# patient age is 64. gender is Male.  height is unavailable.  weight is unavailable.
# 9063
# patient age is 34. gender is Female.  height is unavailable.  weight is unavailable.
# 9064
# patient age is 32. gender is Male.  height is unavailable.  weight is unavailable.
# 9065
# patient age is 61. gender is Male.  height is unavailable.  weight is unavailable.
# 9066
# patient age is 74. gender is Male.  height is unavailable.  weight is unavailable.
# 9067
# patient age is 68. gender is Female.  height is unavailable.  weight is unavailable.
# 9068
# patient age is 67. gender is Male.  height is unavailable.  weight is unavailable.
# 9069
# patient age is 59. gender is Male.  height is unavailable.  weight is unavailable.
# 9070
# patient age is 63. gender is Male.  height is 168. weight is 60 Kilograms.
# 9071
# patient age is 77. gender is Male.  height is unavailable.  weight is unavailable.
# 9072
# patient age is 58. gender is Female.  height is 150. weight is 73 Kilograms.
# 9073
# patient age is 55. gender is Male.  height is 175. weight is 70 Kilograms.
# 9074
# patient age is 90. gender is Female.  height is unavailable.  weight is unavailable.
# 9075
# patient age is 51. gender is Female.  height is unavailable.  weight is unavailable.
# 9076
# patient age is 91. gender is Female.  height is 160. weight is 85 Kilograms.
# 9077
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 9078
# patient age is 57. gender is Male.  height is unavailable.  weight is unavailable.
# 9079
# patient age is 97. gender is Female.  height is 145. weight is 40 Kilograms.
# 9080
# patient age is 74. gender is Male.  height is 171. weight is 70 Kilograms.
# 9081
# patient age is 59. gender is Female.  height is 161. weight is 65 Kilograms.
# 9082
# patient age is 56. gender is Male.  height is 175. weight is 85 Kilograms.
# 9083
# patient age is 93. gender is Male.  height is 160. weight is 80 Kilograms.
# 9084
# patient age is 64. gender is Male.  height is 174. weight is 94 Kilograms.
# 9085
# patient age is 46. gender is Male.  height is 165. weight is 70 Kilograms.
# 9086
# patient age is 84. gender is Female.  height is 155. weight is 70 Kilograms.
# 9087
# patient age is 29. gender is Male.  height is 180. weight is 86 Kilograms.
# 9088
# patient age is 57. gender is Female.  height is unavailable.  weight is unavailable.
# 9089
# patient age is 53. gender is Female.  height is 155. weight is 65 Kilograms.
# 9090
# patient age is 85. gender is Male.  height is 172. weight is 125 Kilograms.
# 9091
# patient age is 71. gender is Female.  height is unavailable.  weight is unavailable.
# 9092
# patient age is 59. gender is Female.  height is 160. weight is 70 Kilograms.
# 9093
# patient age is 70. gender is Female.  height is unavailable.  weight is unavailable.
# 9094
# patient age is 87. gender is Female.  height is 150. weight is 50 Kilograms.
# 9095
# patient age is 87. gender is Male.  height is 160. weight is 65 Kilograms.
# 9096
# patient age is 44. gender is Female.  height is 170.  weight is unavailable.
# 9097
# patient age is 27. gender is Male.  height is 200. weight is 95 Kilograms.
# 9098
# patient age is 59. gender is Female.  height is 160. weight is 70 Kilograms.
# 9099
# patient age is 80. gender is Female.  height is unavailable.  weight is unavailable.
# 9100
# patient age is 63. gender is Male.  height is unavailable.  weight is unavailable.
# 9101
# patient age is 39. gender is Male.  height is 167. weight is 72 Kilograms.
# 9102
# patient age is 70. gender is Female.  height is 160. weight is 70 Kilograms.
# 9103
# patient age is 89. gender is Male.  height is 165. weight is 62 Kilograms.
# 9104
# patient age is 32. gender is Male.  height is 180. weight is 86 Kilograms.
# 9105
# patient age is 94. gender is Male.  height is unavailable.  weight is unavailable.
# 9106
# patient age is 67. gender is Male.  height is 167. weight is 72 Kilograms.
# 9107
# patient age is 47. gender is Male.  height is 180. weight is 75 Kilograms.
# 9108
# patient age is 77. gender is Male.  height is 170. weight is 75 Kilograms.
# 9109
# patient age is 59. gender is Female.  height is 160. weight is 70 Kilograms.
# 9110
# patient age is 47. gender is Male.  height is 175. weight is 70 Kilograms.
# 9111
# patient age is 43. gender is Male.  height is 170. weight is 80 Kilograms.
# 9112
# patient age is 47. gender is Male.  height is unavailable.  weight is unavailable.
# 9113
# patient age is 75. gender is Female.  height is 165. weight is 82 Kilograms.
# 9114
# patient age is 70. gender is Male.  height is unavailable.  weight is unavailable.
# 9115
# patient age is 79. gender is Male.  height is unavailable.  weight is unavailable.
# 9116
# patient age is 41. gender is Male.  height is unavailable.  weight is unavailable.
# 9117
# patient age is 45. gender is Female.  height is 175. weight is 76 Kilograms.
# 9118
# patient age is 65. gender is Male.  height is 178. weight is 80 Kilograms.
# 9119
# patient age is 64. gender is Male.  height is 180. weight is 85 Kilograms.
# 9120
# patient age is 72. gender is Female.  height is 160. weight is 75 Kilograms.
# 9121
# patient age is 59. gender is Male.  height is unavailable.  weight is unavailable.
# 9122
# patient age is 39. gender is Female.  height is 165. weight is 70 Kilograms.
# 9123
# patient age is 38. gender is Male.  height is unavailable.  weight is unavailable.
# 9124
# patient age is 60. gender is Female.  height is unavailable.  weight is unavailable.
# 9125
# patient age is 43. gender is Male.  height is 170. weight is 130 Kilograms.
# 9126
# patient age is 57. gender is Male.  height is unavailable.  weight is unavailable.
# 9127
# patient age is 59. gender is Male.  height is unavailable.  weight is unavailable.
# 9128
# patient age is 45. gender is Female.  height is 160. weight is 70 Kilograms.
# 9129
# patient age is 73. gender is Female.  height is 150. weight is 75 Kilograms.
# 9130
# patient age is 88. gender is Female.  height is unavailable.  weight is unavailable.
# 9131
# patient age is 51. gender is Male.  height is 175. weight is 70 Kilograms.
# 9132
# patient age is 64. gender is Female.  height is 170. weight is 75 Kilograms.
# 9133
# patient age is 38. gender is Male.  height is 182. weight is 90 Kilograms.
# 9134
# patient age is 91. gender is Male.  height is 165. weight is 65 Kilograms.
