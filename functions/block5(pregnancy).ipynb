# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel("ClincolabratoryAll_Labeled_Cleaned_Anonynimized.xlsx")
block5 = df.loc[: , ['MH_Pregnancy']]

# %%
block5
# Out:
#          MH_Pregnancy
# 0     Pregnancy (0/1)
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 9130                0
# 9131                0
# 9132                0
# 9133                0
# 9134                0
#
# [9135 rows x 1 columns]

# %%
def fun5(info):

    if info=="NAN":
        a ="Pregnancy is unclear. "
    elif info=="1":
        a ="pregnant. "
    else:
        a= "Not pregnant. "
    n=(a)
    return(n)
'''for i in block5.values.tolist():
    print(i)'''

lis5=[]
for i in block5.values.tolist():
    if i!=['Pregnancy (0/1)']:
        for b in i:
            lis5.append(fun5(str(b)))
print(lis5)
# Out:
# ['Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pregnant. ', 'Not pr
# ...
