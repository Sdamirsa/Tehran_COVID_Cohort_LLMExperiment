# %%
import pandas as pd

df= pd.read_excel("ClincolabratoryAll_Labeled_Cleaned_Anonynimized.xlsx")
outcom = df.loc[: , 'Outcome_InhospitalMortality':'Outcome_ICULOS']

# %%
def fun(c):
    x =' '
    for i in c:
        x= x+" "+i
    print(x)


for i in outcom.index:
    if i!=0:
        lis = []
        for a in outcom.loc[i , : ]:
            lis.append(str(a))
        fun(lis)
# Out:
#   Died 30 1 25
#   Died 19 1 15
#   Died 12 1 11
#   Survived 18 1 9
#   Survived 18 1 9
#   Survived 6 0 0
#   Survived 9 0 0
#   Survived 7 0 0
#   Survived 35 1 25
#   Survived 16 1 6
#   Died 5 1 4
#   Survived 5 1 4
#   Survived 5 1 3
#   Died 7 1 2
#   Survived 11 0 0
#   Survived 11 0 0
#   Survived 8 0 0
#   Survived 8 0 0
#   Survived 11 0 0
#   Survived 5 0 0
#   Died 2 0 0
#   Survived 6 0 0
#   Survived 11 0 0
#   Survived 7 0 0
#   Survived 7 0 0
#   Survived 6 0 0
#   Survived 8 0 0
#   Died 21 0 0
#   Survived 10 0 0
#   Died 10 0 0
#   Died 15 0 0
#   Survived 7 0 0
#   Survived 70 1 65
#   Died 35 1 35
#   Survived 39 1 32
#   Died 36 1 32
#   Died 42 1 32
#   Survived 33 1 30
#   Died 31 1 30
#   Survived 41 1 29
#   Died 28 1 28
#   Survived 31 1 27
#   Died 23 1 22
#   Died 19 1 19
#   Survived 23 1 19
#   Died 18 1 18
#   Survived 24 1 18
#   Survived 19 1 17
#   Died 17 1 17
#   Died 21 1 17
#   Died 16 1 16
#   Died 16 1 16
#   Survived 21 1 16
# ...
