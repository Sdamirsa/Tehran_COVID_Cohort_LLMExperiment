# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_excel("ClincolabratoryAll_Labeled_Cleaned_Anonynimized.xlsx")

# %%
head =df.head()
head
# Out:
#          Patient_Number                                      Patient_Phase  \
# 0  Unique id of patient  Patients were included in phase 1 or phase 2 o...
# 1                     1                                            Phase 2
# 2                     2                                            Phase 2
# 3                     3                                            Phase 2
# 4                     4                                            Phase 2
#
#                                     Patient_Hospital  \
# 0  ID of hospital were patient is included (Hospi...
# 1                                          Hospital1
# 2                                          Hospital1
# 3                                          Hospital1
# 4                                          Hospital1
#
#           Patient_AdmitDate     Patient_DischargeDate  \
# 0  Date of admission (days)  Date of discharge (days)
# 1                1400/05/21                       NaN
# ...

# %%
df.shape
# Out:
# (9135, 330)

# %%
df.columns
# Out:
# Index(['Patient_Number', 'Patient_Phase', 'Patient_Hospital',
#        'Patient_AdmitDate', 'Patient_DischargeDate', 'Patient_C19Variant',
#        'Outcome_InhospitalMortality', 'Outcome_LOS', 'Outcome_ICUadmission',
#        'Outcome_ICULOS',
#        ...
#        'LAB_TotalProtein_First', 'LAB_TSH_First', 'LAB_T4_First',
#        'LAB_T3_First', 'LAB_VitD3_First', 'LAB_Zinc_y_First', 'LAB_IgM_First',
#        'LAB_IgG_First', 'LAB_SARSCOV2Egene_First', 'LAB_SARSCOV2RDRP_First'],
#       dtype='object', length=330)

# %%
head.shape
# Out:
# (5, 330)
